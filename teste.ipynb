# %%
import requests

api_key = 'db962bb20df64c6aa67ab069e9d9f51d'

url = f'https://api.spoonacular.com/recipes/716429/information?apiKey={api_key}&includeNutrition=true.'

print(url)
# Out:
# https://api.spoonacular.com/recipes/716429/information?apiKey=db962bb20df64c6aa67ab069e9d9f51d&includeNutrition=true.

# %%
# !pip install requests
# Out:
# ...
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 3.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    ---------------------------------------- 163.8/163.8 kB 9.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/99.6 kB ? eta -:--:--
#    ---------------------------------------- 99.6/99.6 kB 6.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import requests
headers = {
    'User-Agent': 'MeuApp/1.0',
    'Accept': 'application/json'
}
response = requests.get('https://api.spoonacular.com/recipes/716429/information?apiKey=be230203e11244b8b8b4fdbc71adfe93&includeNutrition=true.')
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3-2.0.7-py3.8.egg\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467 try:
# --> 468     self._validate_conn(conn)
#     469 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3-2.0.7-py3.8.egg\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3-2.0.7-py3.8.egg\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
# ...

# %%
request_recipes = 'https://api.spoonacular.com/recipes/findByIngredients?ingredients=potato&apiKey=' + api_key

response_recipes = requests.get(request_recipes)


print(response_recipes)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3-2.0.7-py3.8.egg\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467 try:
# --> 468     self._validate_conn(conn)
#     469 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3-2.0.7-py3.8.egg\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3-2.0.7-py3.8.egg\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     634     warnings.warn(
#     635         (
# ...
